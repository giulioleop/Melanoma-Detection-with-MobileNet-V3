# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation, GlobalAveragePooling2D, Conv2D, MaxPool2D, Flatten
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import pair_confusion_matrix
from sklearn.metrics import confusion_matrix
import itertools
import os
import shutil
import random
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# Path to destination directory where we want subfolders
dest_dir = os.getcwd() + "/gdrive/My Drive/Colab Notebooks/Dissertation/Reorganised_binary/"

# %%
train_path = dest_dir + 'train/'
valid_path = dest_dir + 'valid/'
test_path = dest_dir + 'test/'

# %%
train_batches = ImageDataGenerator ().flow_from_directory(
    directory = train_path, target_size = (224,224), batch_size=32)
valid_batches = ImageDataGenerator ().flow_from_directory(
    directory = valid_path, target_size = (224,224), batch_size=32)
test_batches = ImageDataGenerator ().flow_from_directory(
    directory = test_path, target_size = (224,224), batch_size=32)
# Out:
# Found 1778 images belonging to 2 classes.
# Found 224 images belonging to 2 classes.
# Found 224 images belonging to 2 classes.

# %%
base_model = MobileNetV3Small (weights='imagenet', include_top = False)

x = base_model.output

x = GlobalAveragePooling2D()(x)

preds = Dense(2, activation = 'sigmoid')(x)

base_model=Model (inputs=base_model.input, outputs = preds)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_small_224_1.0_float_no_top_v2.h5
# 4334752/4334752 [==============================] - 0s 0us/step

# %%
base_model.summary()

# %%
for layers in base_model.layers[:-1]:
  layers.trainable = False

# %%
base_model.summary()

# %%
epochs = 20

optimizer = Adam(learning_rate = 0.0001)

m = tf.keras.metrics.SensitivityAtSpecificity(0.5)

n = tf.keras.metrics.SpecificityAtSensitivity(0.5)

base_model.compile(loss = 'binary_crossentropy', optimizer=optimizer, metrics = ['accuracy', m, n])

base_model.fit(x=train_batches, validation_data = valid_batches, epochs = epochs)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 314s 6s/step - loss: 0.7109 - accuracy: 0.5596 - sensitivity_at_specificity: 0.6007 - specificity_at_sensitivity: 0.5928 - val_loss: 0.6913 - val_accuracy: 0.5848 - val_sensitivity_at_specificity: 0.6295 - val_specificity_at_sensitivity: 0.6339
# Epoch 2/20
# 56/56 [==============================] - 31s 560ms/step - loss: 0.6762 - accuracy: 0.6159 - sensitivity_at_specificity: 0.6507 - specificity_at_sensitivity: 0.6637 - val_loss: 0.6725 - val_accuracy: 0.6295 - val_sensitivity_at_specificity: 0.6696 - val_specificity_at_sensitivity: 0.7143
# Epoch 3/20
# 56/56 [==============================] - 33s 594ms/step - loss: 0.6578 - accuracy: 0.6490 - sensitivity_at_specificity: 0.7047 - specificity_at_sensitivity: 0.7148 - val_loss: 0.6582 - val_accuracy: 0.6339 - val_sensitivity_at_specificity: 0.7009 - val_specificity_at_sensitivity: 0.7277
# Epoch 4/20
# 56/56 [==============================] - 34s 594ms/step - loss: 0.6425 - accuracy: 0.6665 - sensitivity_at_specificity: 0.7441 - specificity_at_sensitivity: 0.7615 - val_loss: 0.6453 - val_accuracy: 0.6518 - val_sensitivity_at_specificity: 0.7411 - val_specificity_at_sensitivity: 0.7679
# Epoch 5/20
# 56/56 [==============================] - 33s 587ms/step - loss: 0.6292 - accuracy: 0.6822 - sensitivity_at_specificity: 0.7767 - specificity_at_sensitivity: 0.7840 - val_loss: 0.6349 - val_accuracy: 0.6607 - val_sensitivity_at_specificity: 0.7679 - val_specificity_at_sensitivity: 0.7991
# Epoch 6/20
# 56/56 [==============================] - 36s 643ms/step - loss: 0.6180 - accuracy: 0.6980 - sensitivity_at_specificity: 0.7998 - specificity_at_sensitivity: 0.8088 - val_loss: 0.6253 - val_accuracy: 0.6786 - val_sensitivity_at_specificity: 0.7723 - val_specificity_at_sensitivity: 0.8125
# Epoch 7/20
# 56/56 [==============================] - 34s 609ms/step - loss: 0.6081 - accuracy: 0.6980 - sensitivity_at_specificity: 0.8048 - specificity_at_sensitivity: 0.8251 - val_loss: 0.6166 - val_accuracy: 0.7054 - val_sensitivity_at_specificity: 0.7768 - val_specificity_at_sensitivity: 0.8259
# Epoch 8/20
# 56/56 [==============================] - 34s 598ms/step - loss: 0.5993 - accuracy: 0.7070 - sensitivity_at_specificity: 0.8341 - specificity_at_sensitivity: 0.8363 - val_loss: 0.6095 - val_accuracy: 0.7009 - val_sensitivity_at_specificity: 0.7991 - val_specificity_at_sensitivity: 0.8259
# Epoch 9/20
# 56/56 [==============================] - 34s 613ms/step - loss: 0.5917 - accuracy: 0.7120 - sensitivity_at_specificity: 0.8448 - specificity_at_sensitivity: 0.8515 - val_loss: 0.6033 - val_accuracy: 0.7054 - val_sensitivity_at_specificity: 0.8125 - val_specificity_at_sensitivity: 0.8393
# Epoch 10/20
# 56/56 [==============================] - 34s 609ms/step - loss: 0.5849 - accuracy: 0.7154 - sensitivity_at_specificity: 0.8493 - specificity_at_sensitivity: 0.8616 - val_loss: 0.5976 - val_accuracy: 0.7143 - val_sensitivity_at_specificity: 0.7991 - val_specificity_at_sensitivity: 0.8571
# Epoch 11/20
# 56/56 [==============================] - 33s 597ms/step - loss: 0.5789 - accuracy: 0.7177 - sensitivity_at_specificity: 0.8566 - specificity_at_sensitivity: 0.8667 - val_loss: 0.5919 - val_accuracy: 0.7232 - val_sensitivity_at_specificity: 0.8393 - val_specificity_at_sensitivity: 0.8616
# Epoch 12/20
# 56/56 [==============================] - 33s 596ms/step - loss: 0.5734 - accuracy: 0.7210 - sensitivity_at_specificity: 0.8611 - specificity_at_sensitivity: 0.8690 - val_loss: 0.5878 - val_accuracy: 0.7277 - val_sensitivity_at_specificity: 0.8348 - val_specificity_at_sensitivity: 0.8661
# Epoch 13/20
# 56/56 [==============================] - 33s 592ms/step - loss: 0.5686 - accuracy: 0.7193 - sensitivity_at_specificity: 0.8712 - specificity_at_sensitivity: 0.8774 - val_loss: 0.5837 - val_accuracy: 0.7188 - val_sensitivity_at_specificity: 0.8393 - val_specificity_at_sensitivity: 0.8705
# Epoch 14/20
# 56/56 [==============================] - 32s 571ms/step - loss: 0.5637 - accuracy: 0.7227 - sensitivity_at_specificity: 0.8729 - specificity_at_sensitivity: 0.8813 - val_loss: 0.5796 - val_accuracy: 0.7232 - val_sensitivity_at_specificity: 0.8438 - val_specificity_at_sensitivity: 0.8750
# Epoch 15/20
# 56/56 [==============================] - 35s 618ms/step - loss: 0.5597 - accuracy: 0.7340 - sensitivity_at_specificity: 0.8712 - specificity_at_sensitivity: 0.8825 - val_loss: 0.5763 - val_accuracy: 0.7277 - val_sensitivity_at_specificity: 0.8393 - val_specificity_at_sensitivity: 0.8750
# Epoch 16/20
# 56/56 [==============================] - 33s 597ms/step - loss: 0.5555 - accuracy: 0.7340 - sensitivity_at_specificity: 0.8763 - specificity_at_sensitivity: 0.8813 - val_loss: 0.5729 - val_accuracy: 0.7277 - val_sensitivity_at_specificity: 0.8438 - val_specificity_at_sensitivity: 0.8750
# Epoch 17/20
# 56/56 [==============================] - 35s 627ms/step - loss: 0.5524 - accuracy: 0.7306 - sensitivity_at_specificity: 0.8729 - specificity_at_sensitivity: 0.8836 - val_loss: 0.5703 - val_accuracy: 0.7277 - val_sensitivity_at_specificity: 0.8438 - val_specificity_at_sensitivity: 0.8795
# Epoch 18/20
# 56/56 [==============================] - 34s 601ms/step - loss: 0.5489 - accuracy: 0.7345 - sensitivity_at_specificity: 0.8847 - specificity_at_sensitivity: 0.8836 - val_loss: 0.5669 - val_accuracy: 0.7232 - val_sensitivity_at_specificity: 0.8527 - val_specificity_at_sensitivity: 0.8795
# Epoch 19/20
# 56/56 [==============================] - 31s 560ms/step - loss: 0.5453 - accuracy: 0.7357 - sensitivity_at_specificity: 0.8847 - specificity_at_sensitivity: 0.8881 - val_loss: 0.5640 - val_accuracy: 0.7321 - val_sensitivity_at_specificity: 0.8527 - val_specificity_at_sensitivity: 0.8884
# Epoch 20/20
# 56/56 [==============================] - 35s 629ms/step - loss: 0.5425 - accuracy: 0.7300 - sensitivity_at_specificity: 0.8858 - specificity_at_sensitivity: 0.8915 - val_loss: 0.5615 - val_accuracy: 0.7366 - val_sensitivity_at_specificity: 0.8571 - val_specificity_at_sensitivity: 0.8884

# %%
# save the model and its weights to disk

save_dir = os.getcwd() + "/gdrive/My Drive/Colab Notebooks/Dissertation/My model/"
model_path = save_dir + 'base_model'
base_model.save(model_path)

# %%
# load the saved model from disk
base_model = load_model(model_path)

# %%
losses = pd.DataFrame(base_model.history.history)
losses[['accuracy','val_accuracy']].plot()

# %%
losses[['loss','val_loss']].plot()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# initialize empty lists for storing predictions and true labels
all_preds = []
all_labels = []

m = tf.keras.metrics.SensitivityAtSpecificity(0.5)

n = tf.keras.metrics.SpecificityAtSensitivity(0.5)

# loop over all batches of images in the test set
for i in range(len(test_batches)):
    # get the next batch of images and true labels
    imgs, labels = next(test_batches)
    
    # make predictions for the batch and append them to the list of all predictions
    preds = base_model.predict(imgs)
    all_preds.append(preds)
    
    # append the true labels for the batch to the list of all labels
    all_labels.append(labels)

# concatenate the arrays of all predictions and all labels
all_preds = np.concatenate(all_preds)
all_labels = np.concatenate(all_labels)

# get the predicted classes for all images in the test set
pred_classes = all_preds.argmax(axis=1)

# get the true classes for all images in the test set
true_classes = all_labels.argmax(axis=1)

# compute the accuracy, sensitivity, and specificity for the entire test set
acc = accuracy_score(true_classes, pred_classes)
sensitivity = m(all_labels, all_preds).numpy()
specificity = n(all_labels, all_preds).numpy()

# compute the confusion matrix for the entire test set
cm = confusion_matrix(true_classes, pred_classes)

print('Accuracy:', acc)
print('Sensitivity:', sensitivity)
print('Specificity:', specificity)
print('Confusion matrix:\n', cm)
# Out:
# 1/1 [==============================] - 0s 457ms/step
# 1/1 [==============================] - 1s 646ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 0s 399ms/step
# 1/1 [==============================] - 0s 357ms/step
# 1/1 [==============================] - 0s 354ms/step
# Accuracy: 0.7276785714285714
# Sensitivity: 0.86160713
# Specificity: 0.87053573
# Confusion matrix:
#  [[92 20]
#  [41 71]]
